# %%
#This Explores the dataset and comapre between Samsung and Apple devices sales

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
phone_sales_df = pd.read_csv(r'C:\Users\user\Downloads\MyPortfolioProjects\Phones EDA Using Pandas\phones_data.csv')
phone_sales_df = phone_sales_df.sort_values(by = 'brand_name')
phone_sales_df
# Out:
#       id brand_name                 model_name       os  popularity  \
# 176  176         2E   E450A 2018 DualSim Black  Android         563
# 185  185         2E  F572L 2018 DualSim Silver  Android         567
# 184  184         2E     F572L 2018 DualSim Red  Android         181
# 183  183         2E   F534L 2018 DualSim Black  Android         600
# 177  177         2E         E450R DualSim Gray  Android         571
# ..   ...        ...                        ...      ...         ...
# 664  664       vivo     Y20 4/64GB Nebula Blue  Android         810
# 666  666       vivo           Y30 4/64GB Black  Android         587
# 667  667       vivo            Y30 4/64GB Blue  Android         896
# 658  658       vivo       Y15 4/64GB Aqua Blue  Android         627
# 660  660       vivo    Y15 4/64GB Burgundy Red  Android         573
#
#      best_price  lowest_price  highest_price  sellers_amount  screen_size  \
# 176        1250          1215           1338              18         4.50
# ...

# %%
#getting Samsung phones data
samsung_phones_df = phone_sales_df[phone_sales_df['brand_name'].str.contains('Samsung')]
samsung_phones_df = samsung_phones_df.filter(items=['brand_name','os','popularity','best_price','lowest_price','highest_price','memory_size','battery_size'])
samsung_phones_df
# Out:
#     brand_name       os  popularity  best_price  lowest_price  highest_price  \
# 287    Samsung  Android        1199       17561         14499          18999
# 234    Samsung  Android         173        8965          8230           9499
# 233    Samsung  Android         339        8816          8299          10175
# 232    Samsung  Android         689        5893          5570           6283
# 231    Samsung  Android         346        7071          7032           7129
# ..         ...      ...         ...         ...           ...            ...
# 283    Samsung  Android         800       39524         28381          41999
# 280    Samsung  Android        1080       22670         18920          30778
# 281    Samsung  Android        1146       30008         28948          34505
# 282    Samsung  Android        1013       28896         27149          34640
# 267    Samsung  Android         184       18114         17695          18626
#
#      memory_size  battery_size
# ...

# %%
#getting Apple phones data
apple_phones_df = phone_sales_df[phone_sales_df['brand_name'].str.contains('Apple')]
apple_phones_df = apple_phones_df.filter(items=['brand_name','os','popularity','best_price','lowest_price','highest_price','memory_size','battery_size'])
apple_phones_df
# Out:
#     brand_name   os  popularity  best_price  lowest_price  highest_price  \
# 698      Apple  iOS         943       34617         29610          45999
# 695      Apple  iOS         708       33505         31199          38003
# 694      Apple  iOS         854       21228         19380          24999
# 725      Apple  iOS        1103       46325         43396          57999
# 726      Apple  iOS        1183       25687         23293          31499
# ..         ...  ...         ...         ...           ...            ...
# 773      Apple  iOS        1187       19790         12505          23928
# 774      Apple  iOS        1128       24184         18399          30600
# 749      Apple  iOS        1032       12412          8100          17735
# 747      Apple  iOS        1110       14468          8699          19705
# 748      Apple  iOS         885       16392          7447          22520
#
#      memory_size  battery_size
# 698          512          3190
# ...

# %%
apple_and_samsung_df = samsung_phones_df.merge(apple_phones_df, how='outer')
apple_and_samsung_df
# Out:
#     brand_name       os  popularity  best_price  lowest_price  highest_price  \
# 0      Samsung  Android        1199       17561         14499          18999
# 1      Samsung  Android         173        8965          8230           9499
# 2      Samsung  Android         339        8816          8299          10175
# 3      Samsung  Android         689        5893          5570           6283
# 4      Samsung  Android         346        7071          7032           7129
# ..         ...      ...         ...         ...           ...            ...
# 228      Apple      iOS        1187       19790         12505          23928
# 229      Apple      iOS        1128       24184         18399          30600
# 230      Apple      iOS        1032       12412          8100          17735
# 231      Apple      iOS        1110       14468          8699          19705
# 232      Apple      iOS         885       16392          7447          22520
#
#      memory_size  battery_size
# ...

# %%
apple_and_samsung_df_dummy = apple_and_samsung_df.filter(items=['brand_name','highest_price','best_price','lowest_price'])
apple_and_samsung_df_dummy.set_index('brand_name')
apple_and_samsung_df_dummy = apple_and_samsung_df_dummy.groupby('brand_name')
apple_and_samsung_df_dummy.mean()
# Out:
#             highest_price    best_price  lowest_price
# brand_name
# Apple        27288.747253  22309.351648  19031.857143
# Samsung      18589.345070  15936.309859  14423.056338

# %%
apple_and_samsung_df_dummy_agg = apple_and_samsung_df_dummy.mean()
apple_and_samsung_df_dummy_agg.plot(kind='bar',title='Apple & Samsung Phones Prices', xlabel='Phone Brand', ylabel='Aggregate Price($)')
# Out:
# <Axes: title={'center': 'Apple & Samsung Phones Prices'}, xlabel='Phone Brand', ylabel='Aggregate Price($)'>

# %%
apple_and_samsung_df_dummy2 = apple_and_samsung_df.filter(items=['brand_name','popularity'])
apple_and_samsung_df_dummy2.set_index('brand_name')
apple_and_samsung_df_dummy2 = apple_and_samsung_df_dummy2.groupby('brand_name')
apple_and_samsung_df_dummy_agg2 = apple_and_samsung_df_dummy2.mean()
apple_and_samsung_df_dummy_agg2.plot.barh(title='Popularity', ylabel='Phone Brand', xlabel='Average Popularity')
# Out:
# <Axes: title={'center': 'Popularity'}, xlabel='Average Popularity', ylabel='Phone Brand'>

# %%
#apple_and_samsung_df.sort_values(by = 'popularity', ascending=False).head(50)

# %%
print(plt.style.available)
plt.style.use('seaborn-v0_8-whitegrid')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
