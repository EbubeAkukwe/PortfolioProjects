# %%
#summary

'''
Pros of program:
This program is good for getting quick insights on a Mall or Supermarket Database, supposing you need to check for trends
or find failing products or even to get where to give coupons that'll have minimal or close to zero effect on revenue

The date replace function works great because it works on any month apart from January, February or March which is pretty cool
because you might be working with datasets from all 12 months.
You can copy and use it in your code where you see fit(Change the date in format dd-mm-yyyy to just the month in text)

The only thing that'll need changing is the cities, supossing more branches opened in 10 more cities. I won't have much of a 
problem, I'll just add the letters representing them to the branch list and the city names to the branch_cities dictionary.

Save me alot of stress of having to rewrite every month analysis code for the mall. I'll have time to focus on more important
things like finding trends or suggestion marketing strategies using the insights gotten from the Basket Analysis.

If I leave the mall, the next analyst won't have to rewrite all the code, he'll just have to start from where I stopped and
add to the code, supposing the company implemented a new payment system and opened a Gaming and Accessories section for
example.Really just copy and paste already existing code, with some few changes to make it work.

Last but not the least is that it's freakishly fast in technical terms the Time of Execution is less than 2 seconds
like it dosen't matter how many customers the database got it just runs like breez

Cons of program:
No virtualization

Note:
I added a block of code that saves the output of the function to a text file in format Branch_Month_Member_Analysis.txt
eg Yangow_January_Member_Analysis in folder SuperMarket Basket Analysis in Desktop. Just incase you need to print it out and
find patterns and trends manually by yourself or your collegue.

Ciáo happy coding!

'''

# %%
#Super Market Basket Analysis

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows',1000)

# %%
df = pd.read_csv(r'C:\Users\user\Downloads\MyPortfolioProjects\new\Supermarket Basket Analysis Using SQL\supermarket_sales - Copy.csv')
df.head(20)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 15  299-46-1805      B   Mandalay        Member  Female
# ...

# %%
branch_cities = {'A':'Yangon','B':'Mandalay','C':'Naypytaw'} 
#more branches can be opened in other cities and will be represented with letters
#the function will help to fasten basket analysis of each branch monthly

# %%
#breaking down the dataset

# %%
#Branch A Dataframe
branchA_df = mall_df[mall_df['Branch'] == 'A']
branchA_df
# Out:
#     Branch Customer type  Gender            Product line  Quantity      Total  \
# 567      A        Normal  Female     Fashion accessories         9   621.2430
# 17       A        Normal    Male       Sports and travel         6   457.4430
# 696      A        Member  Female       Sports and travel         4   113.5680
# 245      A        Member    Male      Home and lifestyle         8   399.7560
# 829      A        Member  Female  Electronic accessories        10   779.3100
# 8        A        Member  Female       Health and beauty         2    76.1460
# 92       A        Member  Female       Sports and travel         7   161.5530
# 297      A        Member    Male      Home and lifestyle         6   493.7940
# 679      A        Member    Male      Food and beverages         6   305.5500
# 757      A        Normal  Female      Home and lifestyle         6   608.0760
# 406      A        Normal    Male      Food and beverages         5    72.3975
# ...

# %%
#Analysis Report by Month
#In the report the following will be stated
'''
Branch,Month
Customer type
Number of male in Customer Type
Number of female in Customer Type
Total number of male/female in Customer Type
Product line,Number of Gender(Male/Female) that purchased Product Line
Total Quantity Sold, Total Payment received, Number of cash/Ewallet/Credit card users that purchased Product line

'''
# Out:
# '\nBranch,Month\nCustomer type\nNumber of male in Customer Type\nNumber of female in Customer Type\nTotal number of male/female in Customer Type\nProduct line,Number of Gender(Male/Female) that purchased Product Line\nTotal Quantity Sold, Total Payment received, Number of cash/Ewallet/Credit card users that purchased Product line\n\n'

# %%
#data frame I'll be working with
mall_df = df.sort_values(by = 'Date').filter(items=['Branch','Customer type','Gender','Product line','Quantity','Total','Date','Payment'])
mall_df
# Out:
#     Branch Customer type  Gender            Product line  Quantity      Total  \
# 496      C        Normal  Female  Electronic accessories         2   132.7620
# 484      C        Member  Female       Sports and travel        10   388.2900
# 567      A        Normal  Female     Fashion accessories         9   621.2430
# 523      C        Normal    Male       Health and beauty         2   132.0270
# 970      B        Member  Female      Food and beverages        10   888.6150
# 450      B        Normal  Female  Electronic accessories         6   470.6730
# 17       A        Normal    Male       Sports and travel         6   457.4430
# 696      A        Member  Female       Sports and travel         4   113.5680
# 245      A        Member    Male      Home and lifestyle         8   399.7560
# 829      A        Member  Female  Electronic accessories        10   779.3100
# 856      B        Normal    Male      Food and beverages         8   177.4080
# ...

# %%
#replacing the dates with their respective month in mall_df dataframe
#date replace code
from datetime import datetime,date
x = mall_df
mall_df_copy = x
for i in mall_df_copy['Date'] :
    date1 = i
    date1 = date1.split('/')
    m = date1[0]
    d = date1[1]
    y = date1[2]
    if int(m) < 10 :
        m = '0' + m
    else :
        pass
    if int(d) < 10 :
        d = '0' + d
    else :
        pass
    date = y+'-'+m+'-'+d
    date = datetime.fromisoformat(date)
    month = datetime.strftime(date, "%B")
    mall_df_copy['Date'] = mall_df_copy['Date'].replace(i, month)
#mall_df_copy

# %%
#function for printing each Branch Analysis report
#I did one branch first in my head
#Function to do just how I saw it in my head

customer_type = ['Membership','Normal']
product_line = ['Electronic accessories','Fashion accessories','Food and beverages','Health and beauty','Home and lifestyle','Sports and travel']
#more branches can be opened in the future in different cities...this can be modified in the future
branches = ['A','B','C']
branch_city = {'A':'Yangon','B':'Mandalay','C':'Naypytaw'}
#dates can be more since the dateframe date column can be worked on using the replace date code in cell above
dates = ['January','February','March']
customers = ['Normal','Member']
global branches,branch_city

def print_analysis_branch(branch,month,customer_type) : #branch can be 'A', 'B' or 'C' and the function can be used on more mall branches in future
    try :
        if month not in dates :
            print('Function: print_analysis_branch(branch,month) \n Bad input for month\n Available months = ',dates)
        else :
            pass
        if branch not in branches :
            print('Function: print_analysis_branch(branch,month) \n Bad input for branch\n Available branches = ',branches)
        else :
            pass
        if customer_type not in customers :
            print('Function: print_analysis_branch(branch,month) \n Bad input for customer type\n Available customer types = ',customers)

        #total
        total = 0 #total is the total paymet received for month, X_total is the total payment gotten from X Product line
        total_sales_count = 0
        female_count = 0
        male_count = 0
        total_cash_users = 0
        total_ewallet_users = 0
        total_credit_users = 0
        total_credit_money = 0
        total_ewallet_money = 0
        total_cash_money = 0
        #electronic
        electronic_sales_count = 0
        electronic_total = 0
        electronic_count_male = 0
        electronic_count_female = 0
        electronic_credit_count = 0
        electronic_cash_count = 0
        electronic_ewallet_count = 0
        electronic_total_credit_money = 0
        electronic_total_ewallet_money = 0
        electronic_total_cash_money = 0
        #fashion
        fashion_sales_count = 0
        fashion_total = 0
        fashion_count_male = 0
        fashion_count_female = 0
        fashion_credit_count = 0
        fashion_cash_count = 0
        fashion_ewallet_count = 0
        fashion_total_credit_money = 0
        fashion_total_ewallet_money = 0
        fashion_total_cash_money = 0
        
        #food and beverages
        food_sales_count = 0
        food_total = 0
        food_count_male = 0
        food_count_female = 0
        food_credit_count = 0
        food_cash_count = 0
        food_ewallet_count = 0
        food_total_credit_money = 0
        food_total_ewallet_money = 0
        food_total_cash_money = 0
        
        #health and beauty
        health_sales_count = 0
        health_total = 0
        health_count_male = 0
        health_count_female = 0
        health_credit_count = 0
        health_cash_count = 0
        health_ewallet_count = 0
        health_total_credit_money = 0
        health_total_ewallet_money = 0
        health_total_cash_money = 0
         
        #home and lifestyle
        lifestyle_sales_count = 0
        lifestyle_total = 0
        lifestyle_count_male = 0
        lifestyle_count_female = 0
        lifestyle_credit_count = 0
        lifestyle_cash_count = 0
        lifestyle_ewallet_count = 0
        lifestyle_total_credit_money = 0
        lifestyle_total_ewallet_money = 0
        lifestyle_total_cash_money = 0
        
        #sports and travel
        sports_sales_count = 0
        sports_total = 0
        sports_count_male = 0
        sports_count_female = 0
        sports_credit_count = 0
        sports_cash_count = 0
        sports_ewallet_count = 0
        sports_total_credit_money = 0
        sports_total_ewallet_money = 0
        sports_total_cash_money = 0

        branch_ = mall_df_copy[mall_df_copy['Branch'] == branch]
        branch_df = branch_[branch_['Customer type'] == customer_type]
        branchmonth = branch_df[branch_df['Date'] == month]
        branchmonth_male = branchmonth[branchmonth['Gender'] == 'Male']
        branchmonth_female = branchmonth[branchmonth['Gender'] == 'Female']
        branchmonth_cash_payment = branchmonth[branchmonth['Payment'] == 'Cash']
        branchmonth_card_payment = branchmonth[branchmonth['Payment'] == 'Credit card']
        branchmonth_wallet_payment = branchmonth[branchmonth['Payment'] == 'Ewallet']
        
        branchmonth_electric = branchmonth[branchmonth['Product line'] == 'Electronic accessories']
        branchmonth_electric_cash_payment = branchmonth_electric[branchmonth_electric['Payment'] == 'Cash']
        branchmonth_electric_card_payment = branchmonth_electric[branchmonth_electric['Payment'] == 'Credit card']
        branchmonth_electric_wallet_payment = branchmonth_electric[branchmonth_electric['Payment'] == 'Ewallet']
        
        branchmonth_fashion = branchmonth[branchmonth['Product line'] == 'Fashion accessories']
        branchmonth_fashion_cash_payment = branchmonth_fashion[branchmonth_fashion['Payment'] == 'Cash']
        branchmonth_fashion_card_payment = branchmonth_fashion[branchmonth_fashion['Payment'] == 'Credit card']
        branchmonth_fashion_wallet_payment = branchmonth_fashion[branchmonth_fashion['Payment'] == 'Ewallet']
        
        branchmonth_food = branchmonth[branchmonth['Product line'] == 'Food and beverages']
        branchmonth_food_cash_payment = branchmonth_food[branchmonth_food['Payment'] == 'Cash']
        branchmonth_food_card_payment = branchmonth_food[branchmonth_food['Payment'] == 'Credit card']
        branchmonth_food_wallet_payment = branchmonth_food[branchmonth_food['Payment'] == 'Ewallet']
        
        branchmonth_health = branchmonth[branchmonth['Product line'] == 'Health and beauty']
        branchmonth_health_cash_payment = branchmonth_health[branchmonth_health['Payment'] == 'Cash']
        branchmonth_health_card_payment = branchmonth_health[branchmonth_health['Payment'] == 'Credit card']
        branchmonth_health_wallet_payment = branchmonth_health[branchmonth_health['Payment'] == 'Ewallet']
        
        branchmonth_lifestyle = branchmonth[branchmonth['Product line'] == 'Home and lifestyle']
        branchmonth_lifestyle_cash_payment = branchmonth_lifestyle[branchmonth_lifestyle['Payment'] == 'Cash']
        branchmonth_lifestyle_card_payment = branchmonth_lifestyle[branchmonth_lifestyle['Payment'] == 'Credit card']
        branchmonth_lifestyle_wallet_payment = branchmonth_lifestyle[branchmonth_lifestyle['Payment'] == 'Ewallet']
        
        branchmonth_sports = branchmonth[branchmonth['Product line'] == 'Sports and travel']
        branchmonth_sports_cash_payment = branchmonth_sports[branchmonth_sports['Payment'] == 'Cash']
        branchmonth_sports_card_payment = branchmonth_sports[branchmonth_sports['Payment'] == 'Credit card']
        branchmonth_sports_wallet_payment = branchmonth_sports[branchmonth_sports['Payment'] == 'Ewallet']
        
        #for loop looping through the data frame and bringing out count and sum values
        #total
        for i in branchmonth['Total'] :
            total += int(i)
            total_sales_count += 1
        for i in branchmonth_cash_payment['Total'] :
            total_cash_money += int(i)
        for i in branchmonth_card_payment['Total'] :
            total_credit_money += int(i)
        for i in branchmonth_wallet_payment['Total'] :
            total_ewallet_money += int(i)
        for i in branchmonth['Gender'] :
            if i == 'Male' :
                male_count += 1
            else :
                pass
        for i in branchmonth['Gender'] :
            if i == 'Female' :
                female_count += 1
            else :
                pass
        for i in branchmonth['Payment'] :
            if i == 'Cash' :
                total_cash_users += 1
            else :
                pass
        for i in branchmonth['Payment'] :
            if i == 'Ewallet' :
                total_ewallet_users += 1
            else :
                pass
        for i in branchmonth['Payment'] :
            if i == 'Credit card' :
                total_credit_users += 1
            else :
                pass
        #electronic
        for i in branchmonth_electric['Total'] :
            electronic_total += int(i)
            electronic_sales_count += 1
        for i in branchmonth_electric_cash_payment['Total'] :
            electronic_total_cash_money += int(i)
        for i in branchmonth_electric_card_payment['Total'] :
            electronic_total_credit_money += int(i)
        for i in branchmonth_electric_wallet_payment['Total'] :
            electronic_total_ewallet_money += int(i)
        for i in branchmonth_electric['Gender'] :
            if i == 'Male' :
                electronic_count_male += 1
            else :
                pass
        for i in branchmonth_electric['Gender'] :
            if i == 'Female' :
                electronic_count_female += 1
            else :
                pass
        for i in branchmonth_electric['Payment'] :
            if i == 'Cash' :
                electronic_cash_count += 1 
            else :
                pass
        for i in branchmonth_electric['Payment'] :
            if i == 'Ewallet' :
                electronic_ewallet_count += 1
            else :
                pass
        for i in branchmonth_electric['Payment'] :
            if i == 'Credit card' :
                electronic_credit_count += 1
            else :
                pass
        #fashion
        for i in branchmonth_fashion['Total'] :
            fashion_total += int(i)
            fashion_sales_count += 1
        for i in branchmonth_fashion_cash_payment['Total'] :
            fashion_total_cash_money += int(i)
        for i in branchmonth_fashion_card_payment['Total'] :
            fashion_total_credit_money += int(i)
        for i in branchmonth_fashion_wallet_payment['Total'] :
            fashion_total_ewallet_money += int(i)
        for i in branchmonth_fashion['Gender'] :
            if i == 'Male' :
                fashion_count_male += 1
            else :
                pass
        for i in branchmonth_fashion['Gender'] :
            if i == 'Female' :
                fashion_count_female += 1
            else :
                pass
        for i in branchmonth_fashion['Payment'] :
            if i == 'Cash' :
                fashion_cash_count += 1
            else :
                pass
        for i in branchmonth_fashion['Payment'] :
            if i == 'Ewallet' :
                fashion_ewallet_count += 1
            else :
                pass
        for i in branchmonth_fashion['Payment'] :
            if i == 'Credit card' :
                fashion_credit_count += 1
            else :
                pass
        #food and beverages
        for i in branchmonth_food['Total'] :
            food_total += int(i)
            food_sales_count += 1
        for i in branchmonth_food_cash_payment['Total'] :
            food_total_cash_money += int(i)
        for i in branchmonth_food_card_payment['Total'] :
            food_total_credit_money += int(i)
        for i in branchmonth_food_wallet_payment['Total'] :
            food_total_ewallet_money += int(i)
        for i in branchmonth_food['Gender'] :
            if i == 'Male' :
                food_count_male += 1
            else :
                pass
        for i in branchmonth_food['Gender'] :
            if i == 'Female' :
                food_count_female += 1
            else :
                pass
        for i in branchmonth_food['Payment'] :
            if i == 'Cash' :
                food_cash_count += 1
            else :
                pass
        for i in branchmonth_food['Payment'] :
            if i == 'Ewallet' :
                food_ewallet_count += 1
            else :
                pass
        for i in branchmonth_food['Payment'] :
            if i == 'Credit card' :
                food_credit_count += 1
            else :
                pass
        #health and beauty
        for i in branchmonth_health['Total'] :
            health_total += int(i)
            health_sales_count += 1
        for i in branchmonth_health_cash_payment['Total'] :
            health_total_cash_money += int(i)
        for i in branchmonth_health_card_payment['Total'] :
            health_total_credit_money += int(i)
        for i in branchmonth_health_wallet_payment['Total'] :
            health_total_ewallet_money += int(i)
        for i in branchmonth['Gender'] :
            if i == 'Male' :
                health_count_male += 1
            else :
                pass
        for i in branchmonth_health['Gender'] :
            if i == 'Female' :
                health_count_female += 1
            else :
                pass
        for i in branchmonth_health['Payment'] :
            if i == 'Cash' :
                health_cash_count += 1
            else :
                pass
        for i in branchmonth_health['Payment'] :
            if i == 'Ewallet' :
                health_ewallet_count += 1
            else :
                pass
        for i in branchmonth_health['Payment'] :
            if i == 'Credit card' :
                health_credit_count += 1
            else :
                pass
        #home and lifestyle
        for i in branchmonth_lifestyle['Total'] :
            lifestyle_total += int(i)
            lifestyle_sales_count += 1
        for i in branchmonth_lifestyle_cash_payment['Total'] :
            lifestyle_total_cash_money += int(i)
        for i in branchmonth_lifestyle_card_payment['Total'] :
            lifestyle_total_credit_money += int(i)
        for i in branchmonth_lifestyle_wallet_payment['Total'] :
            lifestyle_total_ewallet_money += int(i)
        for i in branchmonth_lifestyle['Gender'] :
            if i == 'Male' :
                lifestyle_count_male += 1
            else :
                pass
        for i in branchmonth_lifestyle['Gender'] :
            if i == 'Female' :
                lifestyle_count_female += 1
            else :
                pass
        for i in branchmonth_lifestyle['Payment'] :
            if i == 'Cash' :
                lifestyle_cash_count += 1
            else :
                pass
        for i in branchmonth_lifestyle['Payment'] :
            if i == 'Ewallet' :
                lifestyle_ewallet_count += 1
            else :
                pass
        for i in branchmonth_lifestyle['Payment'] :
            if i == 'Credit card' :
                lifestyle_credit_count += 1
            else :
                pass
        #sports and travel
        for i in branchmonth_sports['Total'] :
            sports_total += int(i)
            sports_sales_count += 1
        for i in branchmonth_sports_cash_payment['Total'] :
            sports_total_cash_money += int(i)
        for i in branchmonth_sports_card_payment['Total'] :
            sports_total_credit_money += int(i)
        for i in branchmonth_sports_wallet_payment['Total'] :
            sports_total_ewallet_money += int(i)
        for i in branchmonth_sports['Gender'] :
            if i == 'Male' :
                sports_count_male += 1
            else :
                pass
        for i in branchmonth_sports['Gender'] :
            if i == 'Female' :
                sports_count_female += 1
            else :
                pass
        for i in branchmonth_sports['Payment'] :
            if i == 'Cash' :
                sports_cash_count += 1
            else :
                pass
        for i in branchmonth_sports['Payment'] :
            if i == 'Ewallet' :
                sports_ewallet_count += 1
            else :
                pass
        for i in branchmonth_sports['Payment'] :
            if i == 'Credit card' :
                sports_credit_count += 1
            else :
                pass
        
        #PRINTING THE ANALYSIS REPORT
        
        head = 'Mall Basket Analysis Report'
        design = '='
        design_ = '.'
        design1 = design*(len(head)+100)
        design2 = design_*(len(head)+100)
        month_text = month + ' Analysis Report'
        design3 = '-'*(15+(len(customer_type)))
        #reporthead
        print(head.rjust(len(head)+42))
        print(design1+'\n')
        #branchhead
        print('Branch '+str(branch)+'('+str(branch_cities[branch])+')')
        print(month+' for Customers')
        print(design2)
        print('Customer Type: ' + customer_type)
        print(design3)
        print('Total Number of customers: '+ str(male_count+female_count))
        print((' '*5)+('Number of male customers: ' + str(male_count)))
        print((' '*5)+('Number of female customers: ' + str(female_count)))
        print(design3*2)
        #print total
        print('Total sales: ' + str(total_sales_count))
        print('Total money received via Payment: ' + str(total))
        print((' '*5)+('Credit users: '+ str(total_credit_users)))
        print((' '*10)+('Total money received from Credit users: '+str(total_credit_money)))
        print((' '*5)+('Ewallet users: '+str(total_ewallet_users)))
        print((' '*10)+('Total money received from Ewallet users: '+str(total_ewallet_money)))
        print((' '*5)+('Cash users: '+str(total_cash_users)))
        print((' '*10)+('Total money received from Cash users: '+str(total_cash_money)))
        print(design3*2)
        
        #print Product line analysis
        print('Product line')
        print(design3*2)
        
        #print electronic
        print('Total sales of electronic products: ' + str(electronic_sales_count))
        print('Total money received for electronic sales via Payment: ' + str(electronic_total))
        print((' '*5)+('Credit users: '+str(electronic_credit_count)))
        print((' '*10)+('Total money received from Credit users: '+str(electronic_total_credit_money)))
        print((' '*5)+('Ewallet users: '+str(electronic_ewallet_count)))
        print((' '*10)+('Total money received from Ewallet users: '+str(electronic_total_ewallet_money)))
        print((' '*5)+('Cash users: '+str(electronic_cash_count)))
        print((' '*10)+('Total money received from Cash users: '+str(electronic_total_cash_money)))
        print(design3*2)
        
        #print fashion
        print('Total sales of fashion products: ' + str(fashion_sales_count))
        print('Total money received for fashion sales via Payment: ' + str(fashion_total))
        print((' '*5)+('Credit users: '+str(fashion_credit_count)))
        print((' '*10)+('Total money received from Credit users: '+str(fashion_total_credit_money)))
        print((' '*5)+('Ewallet users: '+str(fashion_ewallet_count)))
        print((' '*10)+('Total money received from Ewallet users: '+str(fashion_total_ewallet_money)))
        print((' '*5)+('Cash users: '+str(fashion_cash_count)))
        print((' '*10)+('Total money received from Cash users: '+str(fashion_total_cash_money)))
        print(design3*2)
        
        #print food and beverages
        print('Total sales of food and beverages products: ' + str(food_sales_count))
        print('Total money received for food and beverages sales via Payment: ' + str(food_total))
        print((' '*5)+('Credit users: '+str(food_credit_count)))
        print((' '*10)+('Total money received from Credit users: '+str(food_total_credit_money)))
        print((' '*5)+('Ewallet users: '+str(food_ewallet_count)))
        print((' '*10)+('Total money received from Ewallet users: '+str(food_total_ewallet_money)))
        print((' '*5)+('Cash users: '+str(food_cash_count)))
        print((' '*10)+('Total money received from Cash users: '+str(food_total_cash_money)))
        print(design3*2)
        
        #print health and beauty
        print('Total sales of health and beauty products: ' + str(health_sales_count))
        print('Total money received for health and beauty products sales via Payment: ' + str(health_total))
        print((' '*5)+('Credit users: '+str(health_credit_count)))
        print((' '*10)+('Total money received from Credit users: '+str(health_total_credit_money)))
        print((' '*5)+('Ewallet users: '+str(health_ewallet_count)))
        print((' '*10)+('Total money received from Ewallet users: '+str(health_total_ewallet_money)))
        print((' '*5)+('Cash users: '+str(health_cash_count)))
        print((' '*10)+('Total money received from Cash users: '+str(health_total_cash_money)))
        print(design3*2)
        
        #print lifestyle and home
        print('Total sales of lifestyle and home products: ' + str(lifestyle_sales_count))
        print('Total money received for lifestyle and home products sales via Payment: ' + str(lifestyle_total))
        print((' '*5)+('Credit users: '+str(lifestyle_credit_count)))
        print((' '*10)+('Total money received from Credit users: '+str(lifestyle_total_credit_money)))
        print((' '*5)+('Ewallet users: '+str(lifestyle_ewallet_count)))
        print((' '*10)+('Total money received from Ewallet users: '+str(lifestyle_total_ewallet_money)))
        print((' '*5)+('Cash users: '+str(lifestyle_cash_count)))
        print((' '*10)+('Total money received from Cash users: '+str(lifestyle_total_cash_money)))
        print(design3*2)
        
        #print sports and travel
        print('Total sales of sports and travel products: ' + str(sports_sales_count))
        print('Total money received for sports and travel products sales via Payment: ' + str(sports_total))
        print((' '*5)+('Credit users: '+str(sports_credit_count)))
        print((' '*10)+('Total money received from Credit users: '+str(sports_total_credit_money)))
        print((' '*5)+('Ewallet users: '+str(sports_ewallet_count)))
        print((' '*10)+('Total money received from Ewallet users: '+str(sports_total_ewallet_money)))
        print((' '*5)+('Cash users: '+str(sports_cash_count)))
        print((' '*10)+('Total money received from Cash users: '+str(sports_total_cash_money)))
        print(design3*2)
        
    except UnboundLocalError :
        print(Error)



a = input('Enter branch for analysis: ')
b = input('Enter month to check: ')
c = input('Enter Customer type: ')
print_analysis_branch(a,b,c)
# Out:
# Enter branch for analysis: A
# Enter month to check: January
# Enter Customer type: Member
#                                           Mall Basket Analysis Report
# ...
#
# Branch A(Yangon)
# January for Customers
# ...............................................................................................................................
# Customer Type: Member
# ---------------------
# Total Number of customers: 59
#      Number of male customers: 36
#      Number of female customers: 23
# ------------------------------------------
# Total sales: 59
# Total money received via Payment: 20171
#      Credit users: 19
#           Total money received from Credit users: 6218
#      Ewallet users: 23
#           Total money received from Ewallet users: 8015
#      Cash users: 17
#           Total money received from Cash users: 5938
# ------------------------------------------
# Product line
# ------------------------------------------
# Total sales of electronic products: 11
# ...

# %%
#like this project? follow me on twitter @ebubeakukwe. Are you an employer?Reach out to me at +2349037358860 or ebubeakukwe@gmail.com
